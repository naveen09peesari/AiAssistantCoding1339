# %% [markdown]
# <a href="https://colab.research.google.com/github/naveen09peesari/AiAssistantCoding1339/blob/main/6_5_Assignment_1339.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #HallTicket : 2303a51339
# Name:P.Naveen
# Batch:20
#
#
# # Task 1 : AI-Based Code Completion for Conditional Eligibility Check
# #prompt Used :
# AI-Based Code Completion for Conditional
# Eligibility Check

# %%
age = int(input("Enter your age: "))
citizen = input("Are you a citizen? (yes/no): ")

if age >= 18 and citizen.lower() == "yes":
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# Enter your age: 18
# Are you a citizen? (yes/no): yes
# You are eligible to vote.

# %% [markdown]
# #Explanation :
# The isalpha() function is used to check whether a character is a letter, so numbers, spaces, and special symbols are ignored. A loop is used to iterate through each character in the given string one by one, allowing the program to examine every letter individually. Based on this check, the program counts vowels and consonants separately by increasing the vowel count when a vowel is found and increasing the consonant count when any other alphabet character is found.
# #Output Verification :
# Enter a String : manoharreddy
# Vowels : 4
# Consonants : 8
# #optimization :
# Used .lower() to avoid case sensitivity issues

# %% [markdown]
# #Task 2 :AI-Based Code Completion for Loop-Based String Processing
# #Prompt :
# Generate Python code to count vowels and consonants in a string
# using a loop.

# %%
text = input("Enter a string: ")
vowels = "aeiouAEIOU"
vowel_count = 0
consonant_count = 0

for char in text:
    if char.isalpha():
        if char in vowels:
            vowel_count += 1
        else:
            consonant_count += 1

print("Vowels:", vowel_count)
print("Consonants:", consonant_count)
# Out:
# Enter a string: manoharreddy
# Vowels: 4
# Consonants: 8

# %% [markdown]
# #Explanation
# In this task, AI-generated code processes a string using a loop to count vowels and consonants. The program accepts a string from the user and initializes counters for vowels and consonants. A for loop is used to iterate through each character in the string. The isalpha() function ensures that only alphabetic characters are counted, ignoring spaces and special symbols. If the character belongs to the vowel set, the vowel counter is increased; otherwise, the consonant counter is incremented. This task highlights effective use of loops and conditional logic for string processing.
# #Output Verification
# Enter a String
# Vowels : 4
# Consonents : 8
# #Improvements :
# Ignored spaces and numbers using isalpha().

# %% [markdown]
# #Task 3 :AI-Assisted Code Completion Reflection Task
# #Library Management System
# #Prompt Used:
# Generate a Python program for a library management system using classes, loops, and conditional statements.

# %%
class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)
        print("Book added successfully")

    def display_books(self):
        if not self.books:
            print("No books available")
        else:
            for book in self.books:
                print(book)

lib = Library()

while True:
    print("\n1. Add Book\n2. Display Books\n3. Exit")
    choice = input("Enter choice: ")

    if choice == "1":
        name = input("Enter book name: ")
        lib.add_book(name)
    elif choice == "2":
        lib.display_books()
    elif choice == "3":
        break
    else:
        print("Invalid choice")
# Out:
# 1. Add Book
# 2. Display Books
# 3. Exit
# Enter choice: 1
# Enter book name: rich dad poor dad
# Book added successfully
#
# 1. Add Book
# 2. Display Books
# 3. Exit
# Enter choice: 2
# rich dad poor dad
#
# 1. Add Book
# 2. Display Books
# 3. Exit
# Enter choice: 1
# Enter book name: atomic habits
# Book added successfully
#
# 1. Add Book
# 2. Display Books
# 3. Exit
# Enter choice: 3

# %% [markdown]
# #Explanation (Library Management System)
#
# This task demonstrates an AI-generated library management system using classes, loops, and conditionals. A Library class is created to store book details, and methods are defined to add and display books. A loop-driven menu allows continuous interaction with the user until they choose to exit. Conditional statements handle user choices such as adding or viewing books. This task shows how AI can generate structured, object-oriented programs, while also requiring human review to improve features and handle edge cases.
# Review of AI Suggestions
# #Review of AI Suggestions
# 1 .Proper use of class<br>
# 2 .Loops and conditionals correctly used<br>
# 3 .No delete/search feature (can be extended)<br>

# %% [markdown]
# # Task 4 :AI-Assisted Code Completion for Class-Based Attendance System
# #Prompt : <br>
# Generate a Python class to mark and display student
# attendance using loops.

# %%
class Attendance:
    def __init__(self):
        self.students = {}

    def mark_attendance(self, name, status):
        self.students[name] = status

    def display_attendance(self):
        for name, status in self.students.items():
            print(name, ":", status)

att = Attendance()
att.mark_attendance("Rahul", "Present")
att.mark_attendance("Anjali", "Absent")
att.display_attendance()
# Out:
# Rahul : Present
# Anjali : Absent

# %% [markdown]
# #Optimization :
#
# Dictionary gives fast access <br>
# Clean and readable structure

# %% [markdown]
# #Task 5 : AI-Based Code Completion for Conditional Menu Navigation (ATM)
# #Prompt Used
# Generate a Python program using loops and conditionals to simulate an ATM menu.

# %%
balance = 10000

while True:
    print("\nATM Menu")
    print("1. Check Balance")
    print("2. Deposit")
    print("3. Withdraw")
    print("4. Exit")

    choice = input("Choose option: ")

    if choice == "1":
        print("Balance:", balance)
    elif choice == "2":
        amount = int(input("Enter deposit amount: "))
        balance += amount
    elif choice == "3":
        amount = int(input("Enter withdrawal amount: "))
        if amount <= balance:
            balance -= amount
        else:
            print("Insufficient balance")
    elif choice == "4":
        break
    else:
        print("Invalid option")
# Out:
# ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Choose option: 1
# Balance: 10000
#
# ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Choose option: 2
# Enter deposit amount: 1200
#
# ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Choose option: 2
# Enter deposit amount: 1200000
#
# ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Choose option: 3
# Enter withdrawal amount: 1200
#
# ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Choose option: 1
# Balance: 1210000
#
# ATM Menu
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Choose option: 4

# %% [markdown]
# #Output Verification
# Deposit and withdrawal work correctly<br>
# Prevents overdraft
#
#
# <hr>
#
# #conclusion :
# AI-based code completion improves productivity and learning speed.
# However, understanding logic, testing output, and optimizing code is the responsibility of the programmer
